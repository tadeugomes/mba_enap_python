# %% [markdown]
# <a href="https://colab.research.google.com/github/alexlopespereira/mba_enap/blob/main/Exercicios/Aula2_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 2 - Exercícios - Estruturas de Dados Nativas do Python

# %% [markdown]
# ### Documentação do Autgrader [Link](https://github.com/alexlopespereira/mba_enap/blob/main/Exercicios/Autograder.ipynb)
#
#
# *   Link para o gabarito das questões
# *   Imports padrão
# *   Instalação
# *   Autenticaçao para nota
# *   Validação

# %% [markdown]
# ---
#
#
# ### Instalação do Autograde e Login com Google

# %%
# !pip install --upgrade ipynb_autograde 1> /dev/null

# %%
# %env  COURSE=mba_enap
from ipynb_autograde.main import init_log, validate
init_log()
email_result=!gcloud config get-value account
if not email_result or 'unset' in email_result[0]:
  # !gcloud auth login

# %% [markdown]
# ---
#
#
# ### **Nota de segurança sobre o Autograde**
# #### Esse autograde restringe as bibliotecas que você pode usar no seu código, remove os seus imports e adiciona os imports previamente permitidos que serão necessários estritamente nos exercícios desta disciplina.
#
#
# ---

# %% [markdown]
# ## Exercícios propostos pelo Prof. Brett A. Becker [1](https://promptly-sigcse.web.app/)

# %% [markdown]
# ### 2.1 Crie um prompt para resolver o problema abaixo

# %% [markdown]
# ![repeat.a8f9f0229668460680f7.png](data:image/png;base64,...)

# %%
prompt21="""AQUI"""

# %%
validate(prompt21, "A2-E1")

# %% [markdown]
# ### 2.2 Crie um prompt para resolver o problema abaixo

# %% [markdown]
# ![arrange.bb9dad5f593b6cd5318d.png](data:image/png;base64,...)

# %%
prompt22="""AQUI"""

# %%
validate(prompt22, "A2-E2")

# %% [markdown]
# ### 2.3 Crie um prompt para resolver o problema abaixo

# %% [markdown]
# ![scramble.2aa4d7d4aec4b1ee726e.png](data:image/png;base64,...)

# %%
prompt23="""AQUI"""

# %%
validate(prompt23, "A2-E3")

# %% [markdown]
# ### 2.4 Crie um prompt para resolver o problema abaixo

# %% [markdown]
# ![initials.bd6cd3899fa2ecad7c73.png](data:image/png;base64,...)

# %%
prompt24="""AQUI"""

# %%
validate(prompt24, "A2-E4")

# %% [markdown]
# ### 2.5 Crie um prompt para resolver o problema abaixo

# %% [markdown]
# ![speak.b5edaeadb30e5e712468.png](data:image/png;base64,...)

# %%
prompt25="""Escreva-me uma função Python com o nome speak que substitui letras que se parecem com numeros pelo proprio numero. Inclua semelhanças tanto com letras minusculas quanto com maiusculas. O t ou T mapeia para o 7. Não substitua o G."""

# %%
validate(prompt25, "A2-E5")

# %% [markdown]
# ### 2.6 Crie um prompt para resolver o problema abaixo

# %% [markdown]
# ![zeros.95adf05c48678e633095.png](data:image/png;base64,...)

# %%
prompt26="""Write me a Python function chamada counter que conte a quatidade de zeros numa lista e retorne a quantidade"""

# %%
validate(prompt26, "A2-E6")
